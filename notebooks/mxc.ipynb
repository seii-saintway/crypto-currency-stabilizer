# %%
# default_exp __init__

# %% [markdown]
# # MXC API
# https://mxcdevelop.github.io/APIDoc/

# %%
# export
import contextlib
import hashlib
import hmac
import os
import requests
import time

from urllib import parse


class MXC(object):

    ROOT_URL = 'https://www.mxc.ceo'
    ERROR_MESSAGES = {
        400: '请求参数无效。',
        401: '签名验证失败。',
        429: '请求过于频繁。',
        10072: '无效的 Access Key。',
        10073: '无效的请求时间。',
        30000: '当前交易对已暂停交易。',
        30001: '当前交易方向不允许下单。',
        30002: '小于最小交易金额。',
        30003: '大于最大交易金额。',
        30004: '持仓不足。',
        30005: '卖出超额。',
        30010: '下单价格超过范围。',
        30016: '暂停交易。',
        30019: '订单集合超出最大允许长度。',
        30020: '受限制的交易对，暂不支持 API 访问。',
        30021: '无效的交易对。',
    }

    def __init__(self, API_KEY, SECRET_KEY):
        self.API_KEY = API_KEY
        self.SECRET_KEY = SECRET_KEY

    @staticmethod
    def _get_server_time():
        return int(time.time())

    def _sign(self, method, path, original_params=None):
        params = {
            'api_key': self.API_KEY,
            'req_time': type(self)._get_server_time(),
        }
        if original_params is not None:
            params.update(original_params)
        params_str = '&'.join('{}={}'.format(k, params[k]) for k in sorted(params))
        to_sign = '\n'.join([method, path, params_str])
        params.update({
            'sign': hmac.new(self.SECRET_KEY.encode(), to_sign.encode(), hashlib.sha256).hexdigest()
        })
        return params

    def _request(self, method, path, params):
        url = '{}{}'.format(type(self).ROOT_URL, path)
        with contextlib.closing(
            requests.request(method, url, params=params)
        ) as response:
            response_json = response.json()
            code = response_json.get('code', 0)
            if code != 200:
                raise Exception(
                    type(self).ERROR_MESSAGES.get(code, response_json.get('msg', '未知错误。'))
                )
            return response_json.get('data', {})

    def get_symbols(self):
        """marget data"""
        method = 'GET'
        path = '/open/api/v2/market/symbols'
        params = {'api_key': self.API_KEY}
        return self._request(method, path, params)

    def get_rate_limit(self):
        """rate limit"""
        method = 'GET'
        path = '/open/api/v2/common/rate_limit'
        params = {'api_key': self.API_KEY}
        return self._request(method, path, params)

    def get_timestamp(self):
        """get current time"""
        method = 'GET'
        path = '/open/api/v2/common/timestamp'
        params = {'api_key': self.API_KEY}
        return self._request(method, path, params)

    def get_ticker(self, symbol):
        """get ticker information"""
        method = 'GET'
        path = '/open/api/v2/market/ticker'
        params = {
            'api_key': self.API_KEY,
            'symbol': symbol,
        }
        return self._request(method, path, params)

    def get_depth(self, symbol, depth):
        """get market depth"""
        method = 'GET'
        path = '/open/api/v2/market/depth'
        params = {
            'api_key': self.API_KEY,
            'symbol': symbol,
            'depth': depth,
        }
        return self._request(method, path, params)

    def get_deals(self, symbol, limit):
        """get deals records"""
        method = 'GET'
        path = '/open/api/v2/market/deals'
        params = {
            'api_key': self.API_KEY,
            'symbol': symbol,
            'limit': limit,
        }
        return self._request(method, path, params)

    def get_kline(self, symbol, interval):
        """k-line data"""
        method = 'GET'
        path = '/open/api/v2/market/kline'
        params = {
            'api_key': self.API_KEY,
            'symbol': symbol,
            'interval': interval,
        }
        return self._request(method, path, params)

    def get_account_info(self):
        """account information"""
        method = 'GET'
        path = '/open/api/v2/account/info'
        params = self._sign(method, path)
        return self._request(method, path, params)

    def _request_with_json(self, method, path, params, json):
        url = '{}{}'.format(type(self).ROOT_URL, path)
        with contextlib.closing(
            requests.request(method, url, params=params, json=json)
        ) as response:
            response_json = response.json()
            code = response_json.get('code', 0)
            if code != 200:
                raise Exception(
                    type(self).ERROR_MESSAGES.get(code, response_json.get('msg', '未知错误。'))
                )
            return response_json.get('data', {})

    def place_order(self, symbol, price, quantity, trade_type, order_type):
        """place order"""
        method = 'POST'
        path = '/open/api/v2/order/place'
        params = self._sign(method, path)
        data = {
            'symbol': symbol,
            'price': price,
            'quantity': quantity,
            'trade_type': trade_type,
            'order_type': order_type,
        }
        return self._request_with_json(method, path, params, data)

    def batch_orders(self, orders):
        """batch order"""
        method = 'POST'
        path = '/open/api/v2/order/place_batch'
        params = self._sign(method, path)
        return self._request_with_json(method, path, params, orders)

    def cancel_order(self, order_id):
        """cancel in batch"""
        method = 'DELETE'
        path = '/open/api/v2/order/cancel'

        origin_trade_no = order_id
        if isinstance(order_id, list):
            origin_trade_no = parse.quote(','.join(order_id))
        params = self._sign(method, path, original_params={'order_ids': origin_trade_no})
        if isinstance(order_id, list):
            params['order_ids'] = ','.join(order_id)

        return self._request(method, path, params)

    def get_open_orders(self, symbol):
        """current orders"""
        method = 'GET'
        path = '/open/api/v2/order/open_orders'

        original_params = {
            'symbol': symbol,
        }
        params = self._sign(method, path, original_params=original_params)

        return self._request(method, path, params)

    def get_all_orders(self, symbol, trade_type):
        """order list"""
        method = 'GET'
        path = '/open/api/v2/order/list'

        original_params = {
            'symbol': symbol,
            'trade_type': trade_type,
        }
        params = self._sign(method, path, original_params=original_params)

        return self._request(method, path, params)

    def query_order(self, order_id):
        """query order"""
        method = 'GET'
        path = '/open/api/v2/order/query'

        origin_trade_no = order_id
        if isinstance(order_id, list):
            origin_trade_no = parse.quote(','.join(order_id))
        original_params = {
            'order_ids': origin_trade_no,
        }
        params = self._sign(method, path, original_params=original_params)
        if isinstance(order_id, list):
            params['order_ids'] = ','.join(order_id)

        return self._request(method, path, params)

    def get_deal_orders(self, symbol):
        """account deal records"""
        method = 'GET'
        path = '/open/api/v2/order/deals'

        original_params = {
            'symbol': symbol,
        }
        params = self._sign(method, path, original_params=original_params)

        return self._request(method, path, params)

    def get_deal_detail(self, order_id):
        """deal detail"""
        method = 'GET'
        path = '/open/api/v2/order/deal_detail'

        original_params = {
            'order_id': order_id,
        }
        params = self._sign(method, path, original_params=original_params)

        return self._request(method, path, params)

# %%
# hide
import os
notebooks_dir = os.getcwd()
project_dir = os.path.dirname(notebooks_dir)

import sys
sys.path.append(project_dir)

# %%
from ccstabilizer import secrets

# %%
MXC(os.environ['MXC_ACCESS_KEY'], os.environ['MXC_SECRET_KEY']).get_deal_orders('AR_USDT')
# Out:
# [{'id': 'e38b467d1bdc4b0cbd95dbc460dfc914',
#   'symbol': 'AR_USDT',
#   'quantity': '0.23',
#   'price': '22.259',
#   'amount': '5.11957',
#   'fee': '0.01023914',
#   'trade_type': 'ASK',
#   'order_id': '57fb12e86abf426eb1a2847a3fd14a8a',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616222096000},
#  {'id': '00ad88da35c54955bfcd020a1c75b340',
#   'symbol': 'AR_USDT',
#   'quantity': '9',
#   'price': '22',
#   'amount': '198',
#   'fee': '0.396',
#   'trade_type': 'BID',
#   'order_id': 'a8678f5d008b4cfb8ab6eed01ff7d2d3',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616221611000},
#  {'id': '228761d1dfa44b609e18a73083c20497',
#   'symbol': 'AR_USDT',
#   'quantity': '1.85',
#   'price': '21.966',
#   'amount': '40.6371',
#   'fee': '0.0812742',
#   'trade_type': 'ASK',
#   'order_id': '88b5b2a2287649a1b61d93cc272bb263',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616221579000},
#  {'id': '284c321ef8654378b2321aa380677df4',
#   'symbol': 'AR_USDT',
#   'quantity': '2.18',
#   'price': '21.636',
#   'amount': '47.16648',
#   'fee': '0.09433296',
#   'trade_type': 'ASK',
#   'order_id': 'f4d690ae4e984a4198c02f5fd7bac4c2',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616219969000},
#  {'id': '1aa97f510110488b958b2d2a220c1284',
#   'symbol': 'AR_USDT',
#   'quantity': '2.58',
#   'price': '21.418',
#   'amount': '55.25844',
#   'fee': '0.11051688',
#   'trade_type': 'ASK',
#   'order_id': '042b37a8a3a94eb9ace903ca1ec2495a',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616219453000},
#  {'id': 'dc8d44ffd5d34d958e2ca6b7beb47aef',
#   'symbol': 'AR_USDT',
#   'quantity': '0.84',
#   'price': '21.219',
#   'amount': '17.82396',
#   'fee': '0.03564792',
#   'trade_type': 'ASK',
#   'order_id': '9940ee8434e5497199904526d5783272',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616219330000},
#  {'id': '0d0452a2a6e14b91b30c502007980a04',
#   'symbol': 'AR_USDT',
#   'quantity': '2',
#   'price': '20.993',
#   'amount': '41.986',
#   'fee': '0.083972',
#   'trade_type': 'ASK',
#   'order_id': '0edfaad305624e7382ab33895332239a',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616219117000},
#  {'id': '23ff7be575ec4bcaa15adf7dfbbfce72',
#   'symbol': 'AR_USDT',
#   'quantity': '0.37',
#   'price': '20.785',
#   'amount': '7.69045',
#   'fee': '0.0153809',
#   'trade_type': 'ASK',
#   'order_id': 'a0a928fbd4bf45198b8904989c3d8454',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616219025000},
#  {'id': '85f33be5258644b3b975c74ae54e5afa',
#   'symbol': 'AR_USDT',
#   'quantity': '0.89',
#   'price': '20.595',
#   'amount': '18.32955',
#   'fee': '0.0366591',
#   'trade_type': 'ASK',
#   'order_id': 'd648d365b1a14caab244df3ffc984313',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616218993000},
#  {'id': 'adbd17ba43614ed58dc4e922179504aa',
#   'symbol': 'AR_USDT',
#   'quantity': '5.04',
#   'price': '20',
#   'amount': '100.8',
#   'fee': '0.2016',
#   'trade_type': 'ASK',
#   'order_id': 'ce33ca5c50344cc59cb5b8ad4e299dae',
#   'is_taker': False,
#   'fee_currency': 'USDT',
#   'create_time': 1616169354000},
#  {'id': 'dca48473696e40a19e3b42a9e77d1a35',
#   'symbol': 'AR_USDT',
#   'quantity': '1.96',
#   'price': '20',
#   'amount': '39.2',
#   'fee': '0.0784',
#   'trade_type': 'ASK',
#   'order_id': 'ce33ca5c50344cc59cb5b8ad4e299dae',
#   'is_taker': False,
#   'fee_currency': 'USDT',
#   'create_time': 1616169349000},
#  {'id': '146c8e2a00c54024a5fb427fbefbe23f',
#   'symbol': 'AR_USDT',
#   'quantity': '0.83',
#   'price': '20.285',
#   'amount': '16.83655',
#   'fee': '0.0336731',
#   'trade_type': 'ASK',
#   'order_id': '673d515a16c944fd8c291b69a827ca78',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616150564000},
#  {'id': 'a3b3d31e3ade424e91ae4a8b6a0c9281',
#   'symbol': 'AR_USDT',
#   'quantity': '0.27',
#   'price': '19.972',
#   'amount': '5.39244',
#   'fee': '0.01078488',
#   'trade_type': 'ASK',
#   'order_id': '32fc0e1198924887999e02279bc06081',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616148084000},
#  {'id': '5d53f58413bc4eb2bd7d7b322c6dd80c',
#   'symbol': 'AR_USDT',
#   'quantity': '0.45',
#   'price': '19.685',
#   'amount': '8.85825',
#   'fee': '0.0177165',
#   'trade_type': 'ASK',
#   'order_id': '507e881df2c64430817d81c24e6dcb67',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616145932000},
#  {'id': '40b108e18484441e8501ca4f6761236a',
#   'symbol': 'AR_USDT',
#   'quantity': '0.27',
#   'price': '19.158',
#   'amount': '5.17266',
#   'fee': '0.01034532',
#   'trade_type': 'ASK',
#   'order_id': 'b4f12ade6eac4304aeff3c53d98dcf38',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616134320000},
#  {'id': 'bb7d0e7217db4eada32ab22c28db3339',
#   'symbol': 'AR_USDT',
#   'quantity': '0.29',
#   'price': '17.856',
#   'amount': '5.17824',
#   'fee': '0.01035648',
#   'trade_type': 'ASK',
#   'order_id': '290d29c0f46f41b89c91ad5c0dc4c0aa',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616131140000},
#  {'id': 'ff4d5a2e09414087aa688d11a84327bb',
#   'symbol': 'AR_USDT',
#   'quantity': '1.09',
#   'price': '16.918',
#   'amount': '18.44062',
#   'fee': '0.03688124',
#   'trade_type': 'BID',
#   'order_id': 'f0841dc6e7c34231ba2f8ae7599b9fe8',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616113898000},
#  {'id': '95a5addc3dd94bf9b7cb366439684636',
#   'symbol': 'AR_USDT',
#   'quantity': '0.59',
#   'price': '18.988',
#   'amount': '11.20292',
#   'fee': '0.02240584',
#   'trade_type': 'ASK',
#   'order_id': '1a9fec17bd3f4901a050dd904af85335',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616087986000},
#  {'id': '46b77a453f644630a93a20a487a070df',
#   'symbol': 'AR_USDT',
#   'quantity': '0.3',
#   'price': '17.098',
#   'amount': '5.1294',
#   'fee': '0.0102588',
#   'trade_type': 'ASK',
#   'order_id': '174b93f9f13d40b49c7b36860a497d91',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616084861000},
#  {'id': '20238e776b074961aa21a4c144a6e20d',
#   'symbol': 'AR_USDT',
#   'quantity': '7.7',
#   'price': '16.915',
#   'amount': '130.2455',
#   'fee': '0.260491',
#   'trade_type': 'BID',
#   'order_id': '3447ce9074954bd4af452ff37a07bc05',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616084315000},
#  {'id': '0beef27629f2403192c9c3914ee642f8',
#   'symbol': 'AR_USDT',
#   'quantity': '0.69',
#   'price': '17.275',
#   'amount': '11.91975',
#   'fee': '0.0238395',
#   'trade_type': 'BID',
#   'order_id': 'd2c22b1a8b334e6788998e15362b4021',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616084253000},
#  {'id': '8da6bc5076404919a800a509d3234412',
#   'symbol': 'AR_USDT',
#   'quantity': '0.69',
#   'price': '17.374',
#   'amount': '11.98806',
#   'fee': '0.02397612',
#   'trade_type': 'BID',
#   'order_id': 'df092fbe3e5946bbaf996eb79b9e4327',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616084191000},
#  {'id': 'ed667ac73e464299bf7862ef0c124680',
#   'symbol': 'AR_USDT',
#   'quantity': '0.54',
#   'price': '17.965',
#   'amount': '9.7011',
#   'fee': '0.0194022',
#   'trade_type': 'BID',
#   'order_id': 'bb4c6e0a6e664fdead43cdf60a412f03',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616083947000},
#  {'id': '68557f79c45f489cb7987017b928966c',
#   'symbol': 'AR_USDT',
#   'quantity': '4',
#   'price': '17.959',
#   'amount': '71.836',
#   'fee': '0.143672',
#   'trade_type': 'BID',
#   'order_id': 'bb4c6e0a6e664fdead43cdf60a412f03',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616083947000},
#  {'id': '535abc5c187c4395950997126b43f62c',
#   'symbol': 'AR_USDT',
#   'quantity': '6',
#   'price': '17.962',
#   'amount': '107.772',
#   'fee': '0.215544',
#   'trade_type': 'BID',
#   'order_id': 'bb4c6e0a6e664fdead43cdf60a412f03',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616083947000},
#  {'id': 'fdb7d5277587421880f42727f139e13a',
#   'symbol': 'AR_USDT',
#   'quantity': '5.26',
#   'price': '17.975',
#   'amount': '94.5485',
#   'fee': '0.189097',
#   'trade_type': 'ASK',
#   'order_id': '1e93bb087bf84c26b91d7e94f95b145c',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616083916000},
#  {'id': '1bfa47bc3db747d6a6cede430885e037',
#   'symbol': 'AR_USDT',
#   'quantity': '0.37',
#   'price': '17.716',
#   'amount': '6.55492',
#   'fee': '0.01310984',
#   'trade_type': 'ASK',
#   'order_id': '55a0d5b99187434aa817a5afc5c9fb1e',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616083884000},
#  {'id': '0cfc540cfd7a4b1a951cacd035616eec',
#   'symbol': 'AR_USDT',
#   'quantity': '3.11',
#   'price': '17.612',
#   'amount': '54.77332',
#   'fee': '0.10954664',
#   'trade_type': 'ASK',
#   'order_id': '8bd9d64adf6e413aa755a3e36719b05c',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616083853000},
#  {'id': 'b963f73ecda146878d644e3fcc944e6a',
#   'symbol': 'AR_USDT',
#   'quantity': '1.04',
#   'price': '17.432',
#   'amount': '18.12928',
#   'fee': '0.03625856',
#   'trade_type': 'ASK',
#   'order_id': 'dad53a5ae48847e1ae14963b34763c57',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616083822000},
#  {'id': '689549af72c349c299cbc82dc5269e07',
#   'symbol': 'AR_USDT',
#   'quantity': '2',
#   'price': '17.028',
#   'amount': '34.056',
#   'fee': '0.068112',
#   'trade_type': 'ASK',
#   'order_id': 'edd6981ddca847e48cb9e690ce674880',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616083730000},
#  {'id': '8c268d5dea5b4f88a0f7971966a1dcfa',
#   'symbol': 'AR_USDT',
#   'quantity': '1.39',
#   'price': '16.498',
#   'amount': '22.93222',
#   'fee': '0.04586444',
#   'trade_type': 'ASK',
#   'order_id': '391b2e79853947f4a9121c8370f44341',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616080820000},
#  {'id': 'b3c8ad1b13024241a5010ecbc2bea3cc',
#   'symbol': 'AR_USDT',
#   'quantity': '0.42',
#   'price': '15.937',
#   'amount': '6.69354',
#   'fee': '0.01338708',
#   'trade_type': 'ASK',
#   'order_id': '8441140e4aaa4418a9b508a598587eaf',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616079573000},
#  {'id': '25b75c8e303e4b988fbb51e32b084c0d',
#   'symbol': 'AR_USDT',
#   'quantity': '0.39',
#   'price': '15.364',
#   'amount': '5.99196',
#   'fee': '0.01198392',
#   'trade_type': 'ASK',
#   'order_id': '0ad01b1e7a8544e4aea0e5eea9727eb7',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1616057777000},
#  {'id': 'af707d90a22a4bb481b23e036d602ea2',
#   'symbol': 'AR_USDT',
#   'quantity': '0.17',
#   'price': '14.067',
#   'amount': '2.39139',
#   'fee': '0.00478278',
#   'trade_type': 'ASK',
#   'order_id': '4b9d9b614e5f4a5b99812b015e60a15b',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615961925000},
#  {'id': '2064e6d7909745d39de0ee5fb31e5725',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '13.901',
#   'amount': '5.00436',
#   'fee': '0.01000872',
#   'trade_type': 'BID',
#   'order_id': '7e05df4b61594f10b957305950bb5b29',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615955407000},
#  {'id': '80d15a4b1fe2426684dbd041ae0a510e',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.073',
#   'amount': '5.06628',
#   'fee': '0.01013256',
#   'trade_type': 'ASK',
#   'order_id': 'e830b413c4484ef3976f51474db0a737',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615954768000},
#  {'id': 'a5a22726e53e476b83d49a070739c7a1',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '13.934',
#   'amount': '5.01624',
#   'fee': '0.01003248',
#   'trade_type': 'BID',
#   'order_id': '3b9aad4bf47a4715b798c440bca03a89',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615796247000},
#  {'id': '8803e9417a7047de9f8b2a7405e391b9',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.081',
#   'amount': '5.06916',
#   'fee': '0.01013832',
#   'trade_type': 'ASK',
#   'order_id': 'ad7f9f63256647cd80822665b6946a42',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615794395000},
#  {'id': '57d86615f2184e1897976c474c717469',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.078',
#   'amount': '5.06808',
#   'fee': '0.01013616',
#   'trade_type': 'ASK',
#   'order_id': '63adcc33bd504e25b1c6fb4ccfd3bfe0',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615794123000},
#  {'id': '3a86e8e3fc784dcebfbc5d3d523e28ab',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '13.962',
#   'amount': '5.02632',
#   'fee': '0.01005264',
#   'trade_type': 'BID',
#   'order_id': '8205e15bd05d482597d1bd0a65d34eda',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615790542000},
#  {'id': '61c182427e9c41efaf6122b1f8dbb537',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '13.973',
#   'amount': '5.03028',
#   'fee': '0.01006056',
#   'trade_type': 'BID',
#   'order_id': '99eb04bc5d684d808470de88d3ed054f',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615790298000},
#  {'id': '24e93e9f7bfe40e1b6af3ce7fa5d0251',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.133',
#   'amount': '5.08788',
#   'fee': '0.01017576',
#   'trade_type': 'ASK',
#   'order_id': '978b3df69f2648ef99f9c2b247c75f01',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615650105000},
#  {'id': '29d89b7137cb4cf69233df57a550fcb3',
#   'symbol': 'AR_USDT',
#   'quantity': '0.43',
#   'price': '13.962',
#   'amount': '6.00366',
#   'fee': '0.01200732',
#   'trade_type': 'BID',
#   'order_id': '2b7761e9d150470fac3b1b600c7c89ad',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615649315000},
#  {'id': 'd9754d4e5e38481088fcf95c2f014f70',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.076',
#   'amount': '5.06736',
#   'fee': '0.01013472',
#   'trade_type': 'ASK',
#   'order_id': '54dcb901eee249dbb813ee911e6d60dc',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615645406000},
#  {'id': '617d4db8070947639e249ce63cc92815',
#   'symbol': 'AR_USDT',
#   'quantity': '7.53',
#   'price': '13.988',
#   'amount': '105.32964',
#   'fee': '0.21065928',
#   'trade_type': 'BID',
#   'order_id': 'c63decb308694971a97d9f311dad6c12',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615630312000},
#  {'id': '00e5f8c36d534ea3a217d168e3159d64',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.212',
#   'amount': '5.11632',
#   'fee': '0.01023264',
#   'trade_type': 'ASK',
#   'order_id': 'c4dd449f55a7447e9e20d0c35b58a254',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615619956000},
#  {'id': 'b8a66b025c024f0b973df930ce9f8e11',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.004',
#   'amount': '5.04144',
#   'fee': '0.01008288',
#   'trade_type': 'BID',
#   'order_id': 'fc8676f76027481da77a533beeee206b',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615609585000},
#  {'id': '3d5f84aefeea440e834925aa116b334b',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.071',
#   'amount': '5.06556',
#   'fee': '0.01013112',
#   'trade_type': 'ASK',
#   'order_id': '23fe196348084361909051195ca1d791',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615605795000},
#  {'id': 'c5d6b742801e4ce898f53f1a4532dd4f',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.004',
#   'amount': '5.04144',
#   'fee': '0.01008288',
#   'trade_type': 'BID',
#   'order_id': '5e430d3db32443cf97554436d1d14d06',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615603733000},
#  {'id': 'ef17864c7cba4682b30b95546397efb5',
#   'symbol': 'AR_USDT',
#   'quantity': '0.36',
#   'price': '14.065',
#   'amount': '5.0634',
#   'fee': '0.0101268',
#   'trade_type': 'ASK',
#   'order_id': 'e22120850eee4ad887658ec599537c4e',
#   'is_taker': True,
#   'fee_currency': 'USDT',
#   'create_time': 1615600527000}]
